# %%
import pandas as pd
 
# Data.tsv is stored locally in the same directory as of this python file
df = pd.read_csv('/content/drive/MyDrive/Learning - FDP etc/MS - GIS (Illinois)/Spring 2023/GGIS 570 - Advanced Spatial Statistics/Final Project/Data/RedFin/zip_code_market_tracker.tsv000',sep = '\t')
display(df)

# %%
df_zip=pd.read_excel('/FinalZipcodes-HawaiiChicago.xlsx')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6911939 entries, 0 to 6911938
# Data columns (total 58 columns):
#  #   Column                          Dtype
# ---  ------                          -----
#  0   period_begin                    object
#  1   period_end                      object
#  2   period_duration                 int64
#  3   region_type                     object
#  4   region_type_id                  int64
#  5   table_id                        int64
#  6   is_seasonally_adjusted          object
#  7   region                          object
#  8   city                            float64
#  9   state                           object
#  10  state_code                      object
#  11  property_type                   object
#  12  property_type_id                int64
#  13  median_sale_price               float64
#  14  median_sale_price_mom           float64
#  15  median_sale_price_yoy           float64
#  16  median_list_price               float64
# ...

# %%
df.head()
# Out:
# ...
#   period_begin  period_end  period_duration region_type  region_type_id  \
# 0   2022-06-01  2022-08-31               90    zip code               2
# 1   2019-12-01  2020-02-29               90    zip code               2
# 2   2012-07-01  2012-09-30               90    zip code               2
# 3   2012-11-01  2013-01-31               90    zip code               2
# 4   2016-04-01  2016-06-30               90    zip code               2
#
#    table_id is_seasonally_adjusted region  city     state state_code  \
# 0     30725                      f  71923   NaN  Arkansas         AR
# 1     21126                      f  49265   NaN  Michigan         MI
# 2     34119                      f  78727   NaN     Texas         TX
# 3     13119                      f  31503   NaN   Georgia         GA
# 4     34063                      f  78648   NaN     Texas         TX
#
#                property_type  property_type_id  median_sale_price  \
# ...

# %%
# Number of characters to remove from the left side
n = 10

# Remove the fixed number of characters from the left side of each value in the column
df['region'] = df['region'].str.slice(n)

# %%
from google.colab import data_table
data_table.enable_dataframe_formatter()

# %%
# Set the display options to show up to 50 columns
pd.set_option('display.max_columns', 60)

# %%
df.head()

# %%
# Extract the values from the 'filter_values_column' into a list
filter_values = df_zip['Zipcode'].tolist()
filter_values
# Out:
# [96756,
#  96815,
#  96753,
#  96840,
#  96732,
#  96766,
#  96746,
#  96701,
#  96725,
#  96738,
#  96720,
#  96718,
#  96714,
#  96761,
#  96722,
#  96778,
#  96707,
#  96793,
#  96740,
#  96819,
#  96826,
#  96779,
#  96708,
#  96813,
#  96731,
#  96792,
#  96771,
#  96749,
#  96744,
#  96926,
#  96703,
#  96730,
#  96734,
#  96728,
#  96719,
#  96785,
#  96713,
#  96791,
#  96717,
#  96750,
#  96776,
#  96737,
#  96789,
#  96755,
#  96704,
#  96710,
#  96768,
#  96764,
#  96770,
#  96754,
#  96748,
#  96790,
#  96781,
#  96735,
#  96786,
#  96843,
#  96760,
#  96825,
#  96712,
#  96795,
#  96814,
#  96783,
#  96848,
#  96822,
#  96743,
#  96841,
#  96821,
#  96762,
#  96726,
#  96773,
#  96808,
#  96816,
#  96772,
#  96818,
#  96765,
#  96817,
#  96858,
#  96777,
#  96706,
#  96796,
#  96727,
#  96186,
#  96863,
#  96788,
#  96830,
#  98622,
#  96797,
#  96763,
#  96752,
#  96782,
#  96774,
#  96854,
#  96715,
#  96741,
#  96780,
#  96721,
#  96820,
#  96784,
#  60637,
#  60613,
# ...

# %%
df['region'] = df['region'].astype('int64')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6911939 entries, 0 to 6911938
# Data columns (total 58 columns):
#  #   Column                          Dtype
# ---  ------                          -----
#  0   period_begin                    object
#  1   period_end                      object
#  2   period_duration                 int64
#  3   region_type                     object
#  4   region_type_id                  int64
#  5   table_id                        int64
#  6   is_seasonally_adjusted          object
#  7   region                          int64
#  8   city                            float64
#  9   state                           object
#  10  state_code                      object
#  11  property_type                   object
#  12  property_type_id                int64
#  13  median_sale_price               float64
#  14  median_sale_price_mom           float64
#  15  median_sale_price_yoy           float64
#  16  median_list_price               float64
# ...

# %%
# Filter the DataFrame based on the values in 'column_name' that are contained in the list
filtered_df = df[df['region'].isin(filter_values)]
filtered_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 65609 entries, 199 to 6911858
# Data columns (total 58 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   period_begin                    65609 non-null  object
#  1   period_end                      65609 non-null  object
#  2   period_duration                 65609 non-null  int64
#  3   region_type                     65609 non-null  object
#  4   region_type_id                  65609 non-null  int64
#  5   table_id                        65609 non-null  int64
#  6   is_seasonally_adjusted          65609 non-null  object
#  7   region                          65609 non-null  int64
#  8   city                            0 non-null      float64
#  9   state                           65609 non-null  object
#  10  state_code                      65609 non-null  object
#  11  property_type                   65609 non-null  object
# ...

# %%
# Save the selected columns to a CSV file
filtered_df.to_csv('/content/drive/MyDrive/Learning - FDP etc/MS - GIS (Illinois)/Spring 2023/GGIS 570 - Advanced Spatial Statistics/Final Project/Data/RedFin/hawaiichicagorealestatedata.csv', index=False)
